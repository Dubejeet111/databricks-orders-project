# %%
from pyspark.sql import functions as F
data = [
    (1, "Laptop", 50000),
    (2, "Phone",30000),
    (3, "Tablet",20000),
    (4, "Watch", 10000),
    (5, "Headphones", 5000),
    (6, "Keyboard",  2000),
    (7, "Mouse", 1000),
    (8, "Monitor", 10000),
    (9, "Speaker", 5000)
]
df = spark.createDataFrame(data, ["id", "product", "price"])

result = df.withColumn("Tax", F.col("price") * 0.38)
display(result)
